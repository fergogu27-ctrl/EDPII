# %% [markdown]
# <a href="https://colab.research.google.com/github/fergogu27-ctrl/EDPII/blob/main/Untitled31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Usamos los numeros aleatorios, estimacion de una integral
# usamos la probabilidad geometrica y la utilizamos para estimar la integlar

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
import random as r
import pandas as pd

# %% [markdown]
# Queremos estimar el valor de la integral
#  $$I=\int_0^{\frac{\pi}{2}}sen (x) dx$$
#
#  Para ello usaremos el estimador
#  $$\hat{I}= \frac{\pi }{2}\frac{n}{N}$$

# %%
x= np.linspace(0,np.pi/2,100)
plt.plot(x,np.sin(x), color='green')
plt.scatter(r.uniform(0,np.pi/2), r.random())

# %%
def test_function(x):
  return np.sin(x)

# %%
def integrate(x1,x2,func=test_function,n=1000):
    X=np.linspace(x1,x2,1000)
    y1=0
    y2=max((func(X)))
    print(x1,x2,y1,y2)
    area=(x2-x1)*(y2-y1)
    check=[]
    xs=[]
    ys=[]
    for i in range(n):
        x=np.random.uniform(x1,x2,1)
        xs.append(x)
        y=np.random.uniform(y1,y2,1)
        ys.append(y)
        if abs(y)>abs(func(x)) or y<0:
            check.append(0)
        else:
            check.append(1)
    return(np.mean(check)*area,xs,ys,check)

# %%
#print(integrate(0,1)[0])
print(integrate(0,1,test_function)[0])
_,x,y,c=integrate(0,1,n=500)
df=pd.DataFrame()
df['x']=x
df['y']=y
df['c']=c

X=np.linspace(0,1,1000)
plt.grid(True)
plt.plot(X,test_function(X))
plt.scatter(df[df['c']==0]['x'],df[df['c']==0]['y'],color='red')
plt.scatter(df[df['c']==1]['x'],df[df['c']==1]['y'],color='blue')
plt.show()
# Out:
# 0 1 0 0.8414709848078965
# 0.4695408095228063
# 0 1 0 0.8414709848078965

# %%
def mc(x1,x2,f,N):      #x1, x2 son  los valos de la integral, n=numero de dardos que hay que lanxar
X = np.linspace(x1, x2, 100)    #Genramos la particion
y1 = 0
y2 = np.max((f(X)))            #Estamos una arreglo para 100 valores de f(x) donde me lanzara el maximo
y_max = 1

exitos=[]
xs=[]
yx=[]

for i in range(N):
    x = r.uniform(x1,x2,1)
    xs.append(x)
    y = r.uniform(y1, y2, 1)
    ys.append(y)
    area=(x2+x1)*(y2-y1)

    if abs(y) > abs(f(x)) or y<0:
      check.append(0)
    else:
      check.append(1)

return (np.mean(check)*area,xs,ys, check)
# Out:
#   File "/tmp/ipykernel_12282/4042114829.py", line 2
#     X = np.linspace(x1, x2, 100)    #Genramos la particion
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def f(x):
  return np.sin(x)

# %%
P=mc(0,np.pi/2,np.sin)
